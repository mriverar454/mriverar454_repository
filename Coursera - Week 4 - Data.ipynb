# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
print("Downloads Completed")
# Out:
# Downloads Completed

# %%
df = pd.read_excel('/Users/martinrivera/Desktop/IBM DS Certificate/Assignments/Capstone_Car_Dataset_Clean.xlsx')

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.head(10)
# Out:
#    price      brand    model  year  mileage   color       state  New (y/n)
# 0   6300     toyota  cruiser  2008   274117   black  new jersey          0
# 1   2899       ford       se  2011   190552  silver   tennessee          0
# 2   5350      dodge      mpv  2018    39590  silver     georgia          0
# 3  25000       ford     door  2014    64146    blue    virginia          0
# 4  27700  chevrolet     1500  2018     6654     red     florida          0
# 5   5700      dodge      mpv  2018    45561   white       texas          0
# 6   7300  chevrolet       pk  2010   149050   black     georgia          0
# 7  13350        gmc     door  2017    23525    gray  california          0
# 8  14600  chevrolet   malibu  2018     9371  silver     florida          0
# 9   5250       ford      mpv  2017    63418   black       texas          0

# %%
df.describe()
# Out:
#         Unnamed: 0         price         year       mileage
# count  2499.000000   2499.000000  2499.000000  2.499000e+03
# mean   1249.000000  18767.671469  2016.714286  5.229869e+04
# std     721.543484  12116.094936     3.442656  5.970552e+04
# min       0.000000      0.000000  1973.000000  0.000000e+00
# 25%     624.500000  10200.000000  2016.000000  2.146650e+04
# 50%    1249.000000  16900.000000  2018.000000  3.536500e+04
# 75%    1873.500000  25555.500000  2019.000000  6.347250e+04
# max    2498.000000  84900.000000  2020.000000  1.017936e+06

# %%
plt.plot(df['mileage'])
plt.show()

# %%
plt.hist(df['mileage'])

# %%
plt.hist(df['price'])
plt.show()
